# %% [markdown]
# <a href="https://colab.research.google.com/github/phongilm20/VietRXhelper_/blob/main/VietRX_test2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 34.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 70.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 103.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="iPUcPiqm01dZRllXPPnN")
project = rf.workspace("algeriateam").project("algeria-drug-label")
version = project.version(2)
dataset = version.download("yolov8")
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=10,
    imgsz=640,
    plots=True
)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val(split='test')
print(f"mAP on Test: {metrics.box.map50}")
# Out:
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 739.7±284.7 MB/s, size: 13.5 KB)
# val: Scanning /content/Algeria-Drug-label-2/test/labels.cache... 77 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 77/77 158.9Kit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 10, len(boxes) = 836. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 2.4it/s 2.1s
#                    all         77        836      0.991      0.987      0.989      0.801
# Speed: 3.4ms preprocess, 2.8ms inference, 0.0ms loss, 2.3ms postprocess per image
# Results saved to /content/runs/detect/val2
# mAP on Test: 0.9888229939917428

# %%
from google.colab import files
files.download('/content/runs/detect/train3/weights/best.pt')
